# %%
from google.colab import files

uploaded = files.upload()  # 选择并上传本地的.zip文件
import zipfile
# Out:
#      <input type="file" id="files-e858c019-8fad-4ccf-a6c5-a41a9081363f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e858c019-8fad-4ccf-a6c5-a41a9081363f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("my_llm-main.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/my_llm-main_1027")  # unzip

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
#  my_llm-main_1027  'my_llm-main (1).zip'   my_llm-main.zip   sample_data

# %%
# !cd ./my_llm-main_1027/

# %%
# !ls
# Out:
#  my_llm-main_1027  'my_llm-main (1).zip'   my_llm-main.zip   sample_data

# %%
cd ./my_llm-main_1027/my_llm-main/
# Out:
# /content/my_llm-main_1027/my_llm-main

# %%
# !pwd
# Out:
# /content/my_llm-main_1027/my_llm-main

# %%
# !python train.py
# Out:
# 从头训练模型
# 模型参数量：151987968
# /content/my_llm-main_1027/my_llm-main/train.py:88: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# 使用weight decay的参数量为151977984,不使用weight decay的参数量为9984
# AdamW optimiser use fused!
# iter: 0, loss: 10.939651489257812
# iter: 1, loss: 10.944473266601562
# iter: 2, loss: 10.92333984375
# iter: 3, loss: 10.903396606445312
# iter: 4, loss: 10.8541259765625
# iter: 5, loss: 10.813720703125
# iter: 6, loss: 10.721664428710938
# iter: 7, loss: 10.633491516113281
# iter: 8, loss: 10.595863342285156
# iter: 9, loss: 10.515945434570312
# iter: 10, loss: 10.361869812011719
# iter: 11, loss: 10.295280456542969
# iter: 12, loss: 10.186477661132812
# iter: 13, loss: 10.091804504394531
# iter: 14, loss: 10.047027587890625
# iter: 15, loss: 9.928642272949219
# iter: 16, loss: 9.768997192382812
# ...

# %%
# !pip install tiktoken
# !python sample.py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.8 MB/s eta 0:00:00
# ...
# load checkpoint from ./checkpoints
# ...

# %%
# !ls ./checkpoints
